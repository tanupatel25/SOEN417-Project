# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder #required for the encoding
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('preprocessed_data.csv')

# %%
def modeling_Feature_Importance(X,y,model):
    # Split data
    X = df.drop(columns=['h1n1_vaccine','seasonal_vaccine','respondent_id','Unnamed: 0'])
    
   
    # Initialize a dictionary to store the accuracy for each feature removed
    accuracy_with_feature_removed = {}

    # Iterate over each feature to remove it and evaluate the model performance without it
    for column in X.columns:
        # Drop the current feature
        X_temp = X.drop(column, axis=1)

        # Split the modified dataset
        X_train_temp, X_test_temp, y_train_temp, y_test_temp = train_test_split(X_temp, y, test_size=0.2, random_state=42)

        # Scale the data
        scaler_temp = StandardScaler()
        X_train_temp_scaled = scaler_temp.fit_transform(X_train_temp)
        X_test_temp_scaled = scaler_temp.transform(X_test_temp)

        # Train and evaluate the KNN model without the current feature
        if (model== "knn"):
            model=KNeighborsClassifier(n_neighbors=5)
            
        else:
            model=RandomForestClassifier()
        model.fit(X_train_temp_scaled, y_train_temp)
        predictions_temp = model.predict(X_test_temp_scaled)
        accuracy_temp = accuracy_score(y_test_temp, predictions_temp)

        # Store the accuracy in the dictionary
        accuracy_with_feature_removed[column] = accuracy_temp

    # Convert the dictionary to a DataFrame for easier analysis and sort by accuracy
    return pd.DataFrame(list(accuracy_with_feature_removed.items()), columns=['Feature Removed', 'Accuracy']).sort_values(by='Accuracy', ascending=False)

# %%
modeling_Feature_Importance(df,df['h1n1_vaccine'], "knn")
# Out:
#                 Feature Removed  Accuracy
# 29                   census_msa  0.838824
# 2     behavioral_antiviral_meds  0.838450
# 1                h1n1_knowledge  0.838263
# 22                         race  0.838076
# 10         doctor_recc_seasonal  0.837888
# 30             household_adults  0.836391
# 23                          sex  0.836391
# 27            employment_status  0.836204
# 31           household_children  0.836204
# 4          behavioral_face_mask  0.836204
# 21                    education  0.836016
# 5         behavioral_wash_hands  0.836016
# 7       behavioral_outside_home  0.836016
# 18            opinion_seas_risk  0.836016
# 8         behavioral_touch_face  0.835829
# 6   behavioral_large_gatherings  0.835829
# 20                    age_group  0.835642
# 24               income_poverty  0.835642
# 3          behavioral_avoidance  0.835455
# 17  opinion_seas_vacc_effective  0.835455
# 11        chronic_med_condition  0.834893
# 25               marital_status  0.834893
# 12         child_under_6_months  0.834332
# 19  opinion_seas_sick_from_vacc  0.834145
# 26                  rent_or_own  0.833770
# 28               hhs_geo_region  0.833396
# 16  opinion_h1n1_sick_from_vacc  0.833396
# 15            opinion_h1n1_risk  0.832834
# 14  opinion_h1n1_vacc_effective  0.829090
# 13                health_worker  0.828903
# 9              doctor_recc_h1n1  0.822164
# 0                  h1n1_concern  0.807563

# %%
modeling_Feature_Importance(df,df['seasonal_vaccine'], "knn")
# Out:
#                 Feature Removed  Accuracy
# 25               marital_status  0.780232
# 15            opinion_h1n1_risk  0.779671
# 4          behavioral_face_mask  0.778922
# 29                   census_msa  0.778735
# 21                    education  0.778547
# 24               income_poverty  0.778360
# 6   behavioral_large_gatherings  0.777799
# 14  opinion_h1n1_vacc_effective  0.777611
# 1                h1n1_knowledge  0.777424
# 23                          sex  0.777237
# 12         child_under_6_months  0.777237
# 7       behavioral_outside_home  0.777237
# 16  opinion_h1n1_sick_from_vacc  0.776863
# 9              doctor_recc_h1n1  0.776863
# 8         behavioral_touch_face  0.776675
# 27            employment_status  0.776488
# 3          behavioral_avoidance  0.776488
# 19  opinion_seas_sick_from_vacc  0.776301
# 28               hhs_geo_region  0.776301
# 30             household_adults  0.775927
# 26                  rent_or_own  0.775739
# 31           household_children  0.775552
# 5         behavioral_wash_hands  0.775365
# 2     behavioral_antiviral_meds  0.775365
# 22                         race  0.774429
# 11        chronic_med_condition  0.772557
# 13                health_worker  0.770124
# 20                    age_group  0.769000
# 10         doctor_recc_seasonal  0.762261
# 17  opinion_seas_vacc_effective  0.760764
# 18            opinion_seas_risk  0.755897
# 0                  h1n1_concern  0.730251

# %%
modeling_Feature_Importance(df,df['h1n1_vaccine'], "random")
# Out:
#                 Feature Removed  Accuracy
# 5         behavioral_wash_hands  0.839012
# 3          behavioral_avoidance  0.838637
# 6   behavioral_large_gatherings  0.837701
# 23                          sex  0.837140
# 24               income_poverty  0.836952
# 25               marital_status  0.836765
# 19  opinion_seas_sick_from_vacc  0.836578
# 7       behavioral_outside_home  0.836391
# 20                    age_group  0.836391
# 31           household_children  0.836204
# 29                   census_msa  0.836204
# 27            employment_status  0.836016
# 28               hhs_geo_region  0.835829
# 10         doctor_recc_seasonal  0.835455
# 17  opinion_seas_vacc_effective  0.835080
# 1                h1n1_knowledge  0.834893
# 0                  h1n1_concern  0.834706
# 8         behavioral_touch_face  0.834706
# 21                    education  0.834332
# 12         child_under_6_months  0.834332
# 30             household_adults  0.834145
# 26                  rent_or_own  0.833957
# 18            opinion_seas_risk  0.833583
# 2     behavioral_antiviral_meds  0.833209
# 22                         race  0.833021
# 13                health_worker  0.832834
# 11        chronic_med_condition  0.832834
# 16  opinion_h1n1_sick_from_vacc  0.831898
# 4          behavioral_face_mask  0.831149
# 15            opinion_h1n1_risk  0.830213
# 14  opinion_h1n1_vacc_effective  0.826657
# 9              doctor_recc_h1n1  0.821041

# %%
modeling_Feature_Importance(df,df['seasonal_vaccine'], "random")
# Out:
#                 Feature Removed  Accuracy
# 5         behavioral_wash_hands  0.783227
# 26                  rent_or_own  0.780419
# 1                h1n1_knowledge  0.777799
# 8         behavioral_touch_face  0.777424
# 27            employment_status  0.777237
# 12         child_under_6_months  0.777237
# 11        chronic_med_condition  0.777050
# 6   behavioral_large_gatherings  0.776488
# 13                health_worker  0.776488
# 28               hhs_geo_region  0.776114
# 14  opinion_h1n1_vacc_effective  0.776114
# 9              doctor_recc_h1n1  0.775739
# 25               marital_status  0.775739
# 2     behavioral_antiviral_meds  0.775552
# 16  opinion_h1n1_sick_from_vacc  0.774991
# 0                  h1n1_concern  0.774803
# 7       behavioral_outside_home  0.774429
# 21                    education  0.774242
# 4          behavioral_face_mask  0.774242
# 15            opinion_h1n1_risk  0.774055
# 24               income_poverty  0.774055
# 30             household_adults  0.774055
# 3          behavioral_avoidance  0.773680
# 22                         race  0.773493
# 31           household_children  0.773493
# 29                   census_msa  0.773119
# 19  opinion_seas_sick_from_vacc  0.772931
# 23                          sex  0.772183
# 20                    age_group  0.766567
# 10         doctor_recc_seasonal  0.761513
# 17  opinion_seas_vacc_effective  0.758143
# 18            opinion_seas_risk  0.753650

# %%
#Note higher accuracy means less useful feature
